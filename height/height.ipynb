# %%
import requests
import json
import numpy as np

# Bounding box for Columbia, SC
min_lon, min_lat = -81.20, 33.90
max_lon, max_lat = -80.95, 34.10

# Resolution of sampling grid (increase for more detail)
num_points = 10

lats = np.linspace(min_lat, max_lat, num_points)
lons = np.linspace(min_lon, max_lon, num_points)

elevation_data = []

url = "https://epqs.nationalmap.gov/v1/json"

for lat in lats:
    for lon in lons:
        params = {
            "x": lon,
            "y": lat,
            "units": "Meters",
            "wkid": 4326
        }

        r = requests.get(url, params=params)
        r.raise_for_status()

        elevation = r.json()["value"]

        elevation_data.append({
            "latitude": lat,
            "longitude": lon,
            "elevation_meters": elevation
        })

print(f"Collected {len(elevation_data)} elevation points.")

with open("columbia_sc_elevation.json", "w") as f:
    json.dump({
        "location": "Columbia, SC",
        "units": "meters",
        "points": elevation_data
    }, f, indent=4)

print("Saved elevation data to columbia_sc_elevation.json")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 28
#      20 for lon in lons:
#      21     params = {
#      22         "x": lon,
#      23         "y": lat,
#      24         "units": "Meters",
#      25         "wkid": 4326
#      26     }
# ---> 28     r = requests.get(url, params=params)
#      29     r.raise_for_status()
#      31     elevation = r.json()["value"]
#
# File c:\Users\syder\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# ...
